# %% [markdown]
# # assignment 1

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=tv+smart+tv&as=on&as-show=on&otracker=AS_Query_PredictiveAutoSuggest_2_0_na_na_na&otracker1=AS_Query_PredictiveAutoSuggest_2_0_na_na_na&as-pos=2&as-type=PREDICTIVE&suggestionId=tv+smart+tv&requestId=0c2a2387-c031-4cab-b42b-52d61f0793b3"

# %%
permission=requests.get(url)

# %%
permission
# Out:
# <Response [200]>

# %%
fk=BeautifulSoup(permission.text)

# %%
fk
# Out:
# <!DOCTYPE html>
# ...

# %%
tv_price=fk.select("._1_WHN1")

# %%
tv_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹33,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹21,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,941</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹29,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,299</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹20,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹30,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹31,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,999</div>,
# ...

# %%
tv_name=fk.select("._4rR01T")

# %%
tv_name
# Out:
# [<div class="_4rR01T">OnePlus Y1 80 cm (32 inch) HD Ready LED Smart Android TV with Dolby Audio</div>,
#  <div class="_4rR01T">Mi 5A 80 cm (32 inch) HD Ready LED Smart Android TV with Dolby Audio (2022 Model)</div>,
#  <div class="_4rR01T">Infinix Y1 80 cm (32 inch) HD Ready LED Smart Linux TV with Wall Mount</div>,
#  <div class="_4rR01T">KODAK 139 cm (55 inch) QLED Ultra HD (4K) Smart Google TV With Dolby Atmos &amp; Dolby Vision</div>,
#  <div class="_4rR01T">Thomson Alpha 80 cm (32 inch) HD Ready LED Smart Linux TV with 30 W Sound Output &amp; Bezel-Less Design</div>,
#  <div class="_4rR01T">OnePlus Y1 100 cm (40 inch) Full HD LED Smart Android TV with Dolby Audio</div>,
#  <div class="_4rR01T">LG 80 cm (32 inch) HD Ready LED Smart WebOS TV</div>,
#  <div class="_4rR01T">KODAK 7XPRO Series 106 cm (42 inch) Full HD LED Smart Android TV</div>,
#  <div class="_4rR01T">OnePlus Y1S 80 cm (32 inch) HD Ready LED Smart Android TV with Android 11 and Bezel-Less Frame</div>,
# ...

# %%
import pandas as p

# %%
tv_table=p.DataFrame(tv_price,columns=["tv price"])

# %%
tv_table
# Out:
#    tv price
# 0   ₹14,999
# 1   ₹12,999
# 2    ₹8,499
# 3   ₹33,999
# 4    ₹7,999
# 5   ₹21,999
# 6   ₹13,941
# 7   ₹15,999
# 8   ₹15,999
# 9    ₹7,999
# 10  ₹12,499
# 11  ₹15,999
# 12  ₹10,999
# 13  ₹14,999
# 14  ₹29,999
# 15  ₹15,299
# 16  ₹16,999
# 17  ₹20,999
# 18  ₹30,490
# 19  ₹31,999
# 20  ₹24,999
# 21  ₹19,999
# 22   ₹9,499
# 23  ₹14,999

# %%
tv_table=p.DataFrame(tv_name,columns=["tv_name"])

# %%
tv_table
# Out:
#                                               tv_name
# 0   OnePlus Y1 80 cm (32 inch) HD Ready LED Smart ...
# 1   Mi 5A 80 cm (32 inch) HD Ready LED Smart Andro...
# 2   Infinix Y1 80 cm (32 inch) HD Ready LED Smart ...
# 3   KODAK 139 cm (55 inch) QLED Ultra HD (4K) Smar...
# 4   Thomson Alpha 80 cm (32 inch) HD Ready LED Sma...
# 5   OnePlus Y1 100 cm (40 inch) Full HD LED Smart ...
# 6      LG 80 cm (32 inch) HD Ready LED Smart WebOS TV
# 7   KODAK 7XPRO Series 106 cm (42 inch) Full HD LE...
# 8   OnePlus Y1S 80 cm (32 inch) HD Ready LED Smart...
# 9   Coocaa 80 cm (32 inch) HD Ready LED Smart Cool...
# 10  SAMSUNG 80 cm (32 Inch) HD Ready LED Smart Tiz...
# 11  Thomson 9A Series 106 cm (42 inch) Full HD LED...
# 12  acer I Series 80 cm (32 inch) HD Ready LED Sma...
# 13  iFFALCON by TCL F53 100 cm (40 inch) Full HD L...
# 14  SAMSUNG Crystal 4K Neo Series 108 cm (43 inch)...
# 15  Thomson 9A Series 98 cm (40 inch) Full HD LED ...
# ...

# %%
tv_table["price"]=tv_price

# %%
tv_table
# Out:
#                                               tv_name      price
# 0   OnePlus Y1 80 cm (32 inch) HD Ready LED Smart ...  [₹14,999]
# 1   Mi 5A 80 cm (32 inch) HD Ready LED Smart Andro...  [₹12,999]
# 2   Infinix Y1 80 cm (32 inch) HD Ready LED Smart ...   [₹8,499]
# 3   KODAK 139 cm (55 inch) QLED Ultra HD (4K) Smar...  [₹33,999]
# 4   Thomson Alpha 80 cm (32 inch) HD Ready LED Sma...   [₹7,999]
# 5   OnePlus Y1 100 cm (40 inch) Full HD LED Smart ...  [₹21,999]
# 6      LG 80 cm (32 inch) HD Ready LED Smart WebOS TV  [₹13,941]
# 7   KODAK 7XPRO Series 106 cm (42 inch) Full HD LE...  [₹15,999]
# 8   OnePlus Y1S 80 cm (32 inch) HD Ready LED Smart...  [₹15,999]
# 9   Coocaa 80 cm (32 inch) HD Ready LED Smart Cool...   [₹7,999]
# 10  SAMSUNG 80 cm (32 Inch) HD Ready LED Smart Tiz...  [₹12,499]
# 11  Thomson 9A Series 106 cm (42 inch) Full HD LED...  [₹15,999]
# 12  acer I Series 80 cm (32 inch) HD Ready LED Sma...  [₹10,999]
# ...
